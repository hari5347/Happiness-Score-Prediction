# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Datasets/Country_Development_Indicators/dev_indicators.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8717 entries, 0 to 8716
# Data columns (total 6 columns):
# Country Name     8714 non-null object
# Country Code     8712 non-null object
# Series Code      8712 non-null object
# 2015 [YR2015]    8712 non-null object
# 2016 [YR2016]    8712 non-null object
# 2017 [YR2017]    8712 non-null object
# dtypes: object(6)
# memory usage: 408.7+ KB

# %%
df.describe()
# Out:
#        Country Name Country Code     Series Code 2015 [YR2015] 2016 [YR2016]  \
# count          8714         8712            8712          8712          8712
# unique          266          264              33          5151          4533
# top     South Sudan          NER  EG.FEC.RNEW.ZS            ..            ..
# freq             33           33             264          3110          3745
#
#        2017 [YR2017]
# count           8712
# unique          2758
# top               ..
# freq            5762

# %%
df.head(10)
# Out:
#   Country Name Country Code              Series Code     2015 [YR2015]  \
# 0  Afghanistan          AFG           EG.ELC.ACCS.ZS              71.5
# 1  Afghanistan          AFG              SE.PRM.TENR                ..
# 2  Afghanistan          AFG        NY.ADJ.NNTY.KD.ZG                ..
# 3  Afghanistan          AFG     NY.ADJ.NNTY.PC.KD.ZG                ..
# 4  Afghanistan          AFG        NY.ADJ.AEDU.GN.ZS  2.64374189312687
# 5  Afghanistan          AFG        NY.ADJ.ICTR.GN.ZS      -10.28844725
# 6  Afghanistan          AFG              SP.POP.DPND  88.7687273393836
# 7  Afghanistan          AFG           SP.DYN.CBRT.IN             33.98
# 8  Afghanistan          AFG  per_si_allsi.cov_q1_tot                ..
# 9  Afghanistan          AFG  per_si_allsi.cov_q5_tot                ..
#
#       2016 [YR2016]     2017 [YR2017]
# 0  84.1371383666992                ..
# 1                ..                ..
# 2                ..                ..
# ...

# %%
df.tail(10)
# Out:
#                                           Country Name Country Code  \
# 8707                                             World          WLD
# 8708                                             World          WLD
# 8709                                             World          WLD
# 8710                                             World          WLD
# 8711                                             World          WLD
# 8712                                               NaN          NaN
# 8713                                               NaN          NaN
# 8714                                               NaN          NaN
# 8715  Data from database: World Development Indicators          NaN
# 8716                          Last Updated: 01/30/2019          NaN
#
#             Series Code     2015 [YR2015]     2016 [YR2016]     2017 [YR2017]
# 8707     AG.SRF.TOTL.K2  132048793.077485  132036620.811879  132036620.811879
# ...

# %%
df.dropna(how='all',inplace=True)

# %%
df.dropna(subset=['Country Code'],inplace=True)

# %%
df.tail()
# Out:
#      Country Name Country Code        Series Code     2015 [YR2015]  \
# 8707        World          WLD     AG.SRF.TOTL.K2  132048793.077485
# 8708        World          WLD  GC.TAX.TOTL.GD.ZS  14.5119458891319
# 8709        World          WLD     NE.TRD.GNFS.ZS   57.829687871238
# 8710        World          WLD  SL.UEM.TOTL.NE.ZS                ..
# 8711        World          WLD        FP.WPI.TOTL                ..
#
#          2016 [YR2016]     2017 [YR2017]
# 8707  132036620.811879  132036620.811879
# 8708  14.4131551859654                ..
# 8709  56.2129029144921  71.7013360797027
# 8710                ..                ..
# 8711                ..                ..

# %%
df_2015 = df.drop(['2016 [YR2016]','2017 [YR2017]','Country Code'],axis=1)
df_2016 = df.drop(['2015 [YR2015]','2017 [YR2017]','Country Code'],axis=1)
df_2017 = df.drop(['2015 [YR2015]','2016 [YR2016]','Country Code'],axis=1)

# %%
df_2015 = df_2015.groupby('Country Name').apply(lambda x:x.iloc[:,1:].T)
df_2016 = df_2016.groupby('Country Name').apply(lambda x:x.iloc[:,1:].T)
df_2017 = df_2017.groupby('Country Name').apply(lambda x:x.iloc[:,1:].T)

# %%
df_2015.head()
# Out:
#                                       7128         7129               7130  \
# Country Name
# Afghanistan  Series Code    EG.ELC.ACCS.ZS  SE.PRM.TENR  NY.ADJ.NNTY.KD.ZG
#              2015 [YR2015]            71.5           ..                 ..
# Albania      Series Code    EG.ELC.ACCS.ZS  SE.PRM.TENR  NY.ADJ.NNTY.KD.ZG
#              2015 [YR2015]             100     95.59661   4.61846802464052
# Algeria      Series Code    EG.ELC.ACCS.ZS  SE.PRM.TENR  NY.ADJ.NNTY.KD.ZG
#
#                                             7131               7132  \
# Country Name
# Afghanistan  Series Code    NY.ADJ.NNTY.PC.KD.ZG  NY.ADJ.AEDU.GN.ZS
#              2015 [YR2015]                    ..   2.64374189312687
# Albania      Series Code    NY.ADJ.NNTY.PC.KD.ZG  NY.ADJ.AEDU.GN.ZS
#              2015 [YR2015]      4.92356707507196   3.22728502181027
# Algeria      Series Code    NY.ADJ.NNTY.PC.KD.ZG  NY.ADJ.AEDU.GN.ZS
#
#                                          7133              7134  \
# ...

# %%
df_2015 = df_2015.reset_index()
df_2016 = df_2016.reset_index()
df_2017 = df_2017.reset_index()

# %%
df_2015.head()
# Out:
#   Country Name        level_1            7128         7129               7130  \
# 0  Afghanistan    Series Code  EG.ELC.ACCS.ZS  SE.PRM.TENR  NY.ADJ.NNTY.KD.ZG
# 1  Afghanistan  2015 [YR2015]            71.5           ..                 ..
# 2      Albania    Series Code  EG.ELC.ACCS.ZS  SE.PRM.TENR  NY.ADJ.NNTY.KD.ZG
# 3      Albania  2015 [YR2015]             100     95.59661   4.61846802464052
# 4      Algeria    Series Code  EG.ELC.ACCS.ZS  SE.PRM.TENR  NY.ADJ.NNTY.KD.ZG
#
#                    7131               7132               7133  \
# 0  NY.ADJ.NNTY.PC.KD.ZG  NY.ADJ.AEDU.GN.ZS  NY.ADJ.ICTR.GN.ZS
# 1                    ..   2.64374189312687       -10.28844725
# 2  NY.ADJ.NNTY.PC.KD.ZG  NY.ADJ.AEDU.GN.ZS  NY.ADJ.ICTR.GN.ZS
# 3      4.92356707507196   3.22728502181027        15.80204856
# 4  NY.ADJ.NNTY.PC.KD.ZG  NY.ADJ.AEDU.GN.ZS  NY.ADJ.ICTR.GN.ZS
#
#                7134            7135     ...              7151         7152  \
# ...

# %%
df_2015.drop(columns='level_1',axis=1,inplace=True)
df_2016.drop(columns='level_1',axis=1,inplace=True)
df_2017.drop(columns='level_1',axis=1,inplace=True)

# %%
columns = df_2015.iloc[0,1:].values
columns = [i for i in columns]
columns.insert(0,'Country Name')

# %%
df_2015=df_2015.iloc[[i for i in range(1,df_2015.shape[0],2)],:]
df_2016=df_2016.iloc[[i for i in range(1,df_2016.shape[0],2)],:]
df_2017=df_2017.iloc[[i for i in range(1,df_2017.shape[0],2)],:]

# %%
df_2015.head()
# Out:
#      Country Name              7128      7129               7130  \
# 1     Afghanistan              71.5        ..                 ..
# 3         Albania               100  95.59661   4.61846802464052
# 5         Algeria  99.3367080688477   99.2671  -2.76044170117467
# 7  American Samoa                ..        ..                 ..
# 9         Andorra               100        ..                 ..
#
#                 7131              7132          7133              7134  \
# 1                 ..  2.64374189312687  -10.28844725  88.7687273393836
# 3   4.92356707507196  3.22728502181027   15.80204856  44.0166438612638
# 5  -4.60959309801964         4.4671956   36.80385887  52.7249187566745
# 7                 ..         11.760709            ..                ..
# 9                 ..              2.44            ..                ..
#
#      7135 7136 ...   7151      7152      7153      7154               7155  \
# ...

# %%
df_2015 = df_2015.reset_index()
df_2016 = df_2016.reset_index()
df_2017 = df_2017.reset_index()

# %%
df_2015.drop(columns='index',inplace=True)
df_2016.drop(columns='index',inplace=True)
df_2017.drop(columns='index',inplace=True)

# %%
df_2015.columns = columns
df_2016.columns = columns
df_2017.columns = columns

# %%
df_2015.head()
# Out:
#      Country Name    EG.ELC.ACCS.ZS SE.PRM.TENR  NY.ADJ.NNTY.KD.ZG  \
# 0     Afghanistan              71.5          ..                 ..
# 1         Albania               100    95.59661   4.61846802464052
# 2         Algeria  99.3367080688477     99.2671  -2.76044170117467
# 3  American Samoa                ..          ..                 ..
# 4         Andorra               100          ..                 ..
#
#   NY.ADJ.NNTY.PC.KD.ZG NY.ADJ.AEDU.GN.ZS NY.ADJ.ICTR.GN.ZS       SP.POP.DPND  \
# 0                   ..  2.64374189312687      -10.28844725  88.7687273393836
# 1     4.92356707507196  3.22728502181027       15.80204856  44.0166438612638
# 2    -4.60959309801964         4.4671956       36.80385887  52.7249187566745
# 3                   ..         11.760709                ..                ..
# 4                   ..              2.44                ..                ..
#
#   SP.DYN.CBRT.IN per_si_allsi.cov_q1_tot     ...     SH.DYN.MORT SP.POP.TOTL  \
# ...

# %%
Year = pd.Series([2015 for i in range(df_2015.shape[0])],name='Year')
df_2015 = pd.concat([df_2015,Year],axis=1)

# %%
df_2015.head()
# Out:
#      Country Name    EG.ELC.ACCS.ZS SE.PRM.TENR  NY.ADJ.NNTY.KD.ZG  \
# 0     Afghanistan              71.5          ..                 ..
# 1         Albania               100    95.59661   4.61846802464052
# 2         Algeria  99.3367080688477     99.2671  -2.76044170117467
# 3  American Samoa                ..          ..                 ..
# 4         Andorra               100          ..                 ..
#
#   NY.ADJ.NNTY.PC.KD.ZG NY.ADJ.AEDU.GN.ZS NY.ADJ.ICTR.GN.ZS       SP.POP.DPND  \
# 0                   ..  2.64374189312687      -10.28844725  88.7687273393836
# 1     4.92356707507196  3.22728502181027       15.80204856  44.0166438612638
# 2    -4.60959309801964         4.4671956       36.80385887  52.7249187566745
# 3                   ..         11.760709                ..                ..
# 4                   ..              2.44                ..                ..
#
#   SP.DYN.CBRT.IN per_si_allsi.cov_q1_tot  ...  SP.POP.TOTL SE.SEC.ENRL.TC.ZS  \
# ...

# %%
Year = pd.Series([2016 for i in range(df_2016.shape[0])],name='Year')
df_2016 = pd.concat([df_2016,Year],axis=1)

# %%
Year = pd.Series([2017 for i in range(df_2017.shape[0])],name='Year')
df_2017 = pd.concat([df_2017,Year],axis=1)

# %%
df_2016.head()
# Out:
#      Country Name    EG.ELC.ACCS.ZS SE.PRM.TENR  NY.ADJ.NNTY.KD.ZG  \
# 0     Afghanistan  84.1371383666992          ..                 ..
# 1         Albania               100    95.65855   3.19661056052152
# 2         Algeria   99.439567565918    99.23121  -4.13398193588279
# 3  American Samoa                ..          ..                 ..
# 4         Andorra               100          ..                 ..
#
#   NY.ADJ.NNTY.PC.KD.ZG NY.ADJ.AEDU.GN.ZS NY.ADJ.ICTR.GN.ZS       SP.POP.DPND  \
# 0                   ..  2.64374189312687      -10.87939183  86.5709321507136
# 1       3.361733691385  3.22728502181027        16.6463675  44.0015401014685
# 2     -5.8681049935129         4.4671956       35.52823676  53.9078874261101
# 3                   ..         11.760709                ..                ..
# 4                   ..              2.44                ..                ..
#
#   SP.DYN.CBRT.IN per_si_allsi.cov_q1_tot  ...  SP.POP.TOTL SE.SEC.ENRL.TC.ZS  \
# ...

# %%
df_2017.head()
# Out:
#      Country Name EG.ELC.ACCS.ZS SE.PRM.TENR NY.ADJ.NNTY.KD.ZG  \
# 0     Afghanistan             ..          ..                ..
# 1         Albania             ..    97.06175                ..
# 2         Algeria             ..    99.44293                ..
# 3  American Samoa             ..          ..                ..
# 4         Andorra             ..          ..                ..
#
#   NY.ADJ.NNTY.PC.KD.ZG NY.ADJ.AEDU.GN.ZS NY.ADJ.ICTR.GN.ZS       SP.POP.DPND  \
# 0                   ..                ..                ..  84.5872779704028
# 1                   ..                ..                ..  44.0595057133346
# 2                   ..                ..                ..  55.0282166293324
# 3                   ..                ..                ..                ..
# 4                   ..                ..                ..                ..
#
#   SP.DYN.CBRT.IN per_si_allsi.cov_q1_tot  ...  SP.POP.TOTL SE.SEC.ENRL.TC.ZS  \
# ...

# %%
df_2015.shape
# Out:
# (264, 35)

# %%
df_2016.shape
# Out:
# (264, 35)

# %%
df_2017.shape
# Out:
# (264, 35)

# %%
df_final = pd.concat([df_2015,df_2016,df_2017])

# %%
df_final.head()
# Out:
#      Country Name    EG.ELC.ACCS.ZS SE.PRM.TENR  NY.ADJ.NNTY.KD.ZG  \
# 0     Afghanistan              71.5          ..                 ..
# 1         Albania               100    95.59661   4.61846802464052
# 2         Algeria  99.3367080688477     99.2671  -2.76044170117467
# 3  American Samoa                ..          ..                 ..
# 4         Andorra               100          ..                 ..
#
#   NY.ADJ.NNTY.PC.KD.ZG NY.ADJ.AEDU.GN.ZS NY.ADJ.ICTR.GN.ZS       SP.POP.DPND  \
# 0                   ..  2.64374189312687      -10.28844725  88.7687273393836
# 1     4.92356707507196  3.22728502181027       15.80204856  44.0166438612638
# 2    -4.60959309801964         4.4671956       36.80385887  52.7249187566745
# 3                   ..         11.760709                ..                ..
# 4                   ..              2.44                ..                ..
#
#   SP.DYN.CBRT.IN per_si_allsi.cov_q1_tot  ...  SP.POP.TOTL SE.SEC.ENRL.TC.ZS  \
# ...

# %%
df_final.sort_values(by='Country Name',inplace=True)
df_final = df_final.reset_index()
df_final.drop(columns=['index'],inplace=True)

# %%
df_final.head()
# Out:
#   Country Name    EG.ELC.ACCS.ZS SE.PRM.TENR NY.ADJ.NNTY.KD.ZG  \
# 0  Afghanistan              71.5          ..                ..
# 1  Afghanistan  84.1371383666992          ..                ..
# 2  Afghanistan                ..          ..                ..
# 3      Albania               100    95.59661  4.61846802464052
# 4      Albania               100    95.65855  3.19661056052152
#
#   NY.ADJ.NNTY.PC.KD.ZG NY.ADJ.AEDU.GN.ZS NY.ADJ.ICTR.GN.ZS       SP.POP.DPND  \
# 0                   ..  2.64374189312687      -10.28844725  88.7687273393836
# 1                   ..  2.64374189312687      -10.87939183  86.5709321507136
# 2                   ..                ..                ..  84.5872779704028
# 3     4.92356707507196  3.22728502181027       15.80204856  44.0166438612638
# 4       3.361733691385  3.22728502181027        16.6463675  44.0015401014685
#
#   SP.DYN.CBRT.IN per_si_allsi.cov_q1_tot  ...  SP.POP.TOTL SE.SEC.ENRL.TC.ZS  \
# ...

# %% [markdown]
# ***

# %%
df1_2015 = pd.read_csv('../Datasets/Country_Happiness_Index/2015.csv')
df1_2016 = pd.read_csv('../Datasets/Country_Happiness_Index/2016.csv')
df1_2017 = pd.read_csv('../Datasets/Country_Happiness_Index/2017.csv')

# %%
df1_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df1_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
df1_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df1_2015 = df1_2015[['Country','Happiness Score']]
df1_2016 = df1_2016[['Country','Happiness Score']]
df1_2017 = df1_2017[['Country','Happiness.Score']]
df1_2017 = df1_2017.rename(columns={'Happiness.Score':'Happiness Score'})

# %%
Year = pd.Series([2015 for i in range(df1_2015.shape[0])],name='Year')
df1_2015 = pd.concat([df1_2015,Year],axis=1)

# %%
Year = pd.Series([2016 for i in range(df1_2016.shape[0])],name='Year')
df1_2016 = pd.concat([df1_2016,Year],axis=1)

# %%
Year = pd.Series([2017 for i in range(df1_2017.shape[0])],name='Year')
df1_2017 = pd.concat([df1_2017,Year],axis=1)

# %%
df1 = pd.concat([df1_2015,df1_2016,df1_2017])

# %%
df1.sort_values(by=['Country','Year'],inplace=True)
df1 = df1.reset_index() 
df1.drop(columns=['index'],inplace=True)

# %%
df1.rename(columns={'Country':'Country Name'},inplace=True)

# %%
df1.head()
# Out:
#   Country Name  Happiness Score  Year
# 0  Afghanistan            3.575  2015
# 1  Afghanistan            3.360  2016
# 2  Afghanistan            3.794  2017
# 3      Albania            4.959  2015
# 4      Albania            4.655  2016

# %% [markdown]
# ***

# %%
df_merged = pd.merge(on=['Country Name','Year'],left=df1,right=df_final)

# %%
df_merged.head()
# Out:
#   Country Name  Happiness Score  Year    EG.ELC.ACCS.ZS SE.PRM.TENR  \
# 0  Afghanistan            3.575  2015              71.5          ..
# 1  Afghanistan            3.360  2016  84.1371383666992          ..
# 2  Afghanistan            3.794  2017                ..          ..
# 3      Albania            4.959  2015               100    95.59661
# 4      Albania            4.655  2016               100    95.65855
#
#   NY.ADJ.NNTY.KD.ZG NY.ADJ.NNTY.PC.KD.ZG NY.ADJ.AEDU.GN.ZS NY.ADJ.ICTR.GN.ZS  \
# 0                ..                   ..  2.64374189312687      -10.28844725
# 1                ..                   ..  2.64374189312687      -10.87939183
# 2                ..                   ..                ..                ..
# 3  4.61846802464052     4.92356707507196  3.22728502181027       15.80204856
# 4  3.19661056052152       3.361733691385  3.22728502181027        16.6463675
#
#         SP.POP.DPND     ...     SH.DYN.MORT SP.POP.TOTL SE.SEC.ENRL.TC.ZS  \
# ...

# %%
df_merged.sort_values(by=['Country Name','Year'],inplace=True)
df_merged.reset_index(inplace=True)
df_merged.drop('index',axis=1,inplace=True)

# %%
df_merged.head()
# Out:
#   Country Name  Happiness Score  Year    EG.ELC.ACCS.ZS SE.PRM.TENR  \
# 0  Afghanistan            3.575  2015              71.5          ..
# 1  Afghanistan            3.360  2016  84.1371383666992          ..
# 2  Afghanistan            3.794  2017                ..          ..
# 3      Albania            4.959  2015               100    95.59661
# 4      Albania            4.655  2016               100    95.65855
#
#   NY.ADJ.NNTY.KD.ZG NY.ADJ.NNTY.PC.KD.ZG NY.ADJ.AEDU.GN.ZS NY.ADJ.ICTR.GN.ZS  \
# 0                ..                   ..  2.64374189312687      -10.28844725
# 1                ..                   ..  2.64374189312687      -10.87939183
# 2                ..                   ..                ..                ..
# 3  4.61846802464052     4.92356707507196  3.22728502181027       15.80204856
# 4  3.19661056052152       3.361733691385  3.22728502181027        16.6463675
#
#         SP.POP.DPND     ...     SH.DYN.MORT SP.POP.TOTL SE.SEC.ENRL.TC.ZS  \
# ...

# %%
df_merged['Country Name'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain',
#        'Bangladesh', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Costa Rica', 'Croatia', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Djibouti', 'Dominican Republic',
#        'Ecuador', 'El Salvador', 'Estonia', 'Ethiopia', 'Finland',
#        'France', 'Gabon', 'Georgia', 'Germany', 'Ghana', 'Greece',
#        'Guatemala', 'Guinea', 'Haiti', 'Honduras', 'Hungary', 'Iceland',
#        'India', 'Indonesia', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Kosovo',
#        'Kuwait', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya',
# ...

# %% [markdown]
# ***

# %%
df = pd.read_csv('../Datasets/Country_Development_Indicators/WDICountry.csv')

# %%
df.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  Central Bureau of Statistics and Central Bank ...
# 1  Central Statistics Organization; World Bank st...
# 2  IMF ; Source of population estimates: UN Popul...
# 3  Albanian Institute of Statistics ; Source of p...
# 4  Government of Andorra, Department of Statistic...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 31 columns):
# Country Code                                         263 non-null object
# Short Name                                           263 non-null object
# Table Name                                           263 non-null object
# Long Name                                            263 non-null object
# 2-alpha code                                         261 non-null object
# Currency Unit                                        217 non-null object
# Special Notes                                        250 non-null object
# Region                                               217 non-null object
# Income Group                                         217 non-null object
# WB-2 code                                            262 non-null object
# National accounts base year                          206 non-null object
# ...

# %%
df.columns
# Out:
# Index(['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code',
#        'Currency Unit', 'Special Notes', 'Region', 'Income Group', 'WB-2 code',
#        'National accounts base year', 'National accounts reference year',
#        'SNA price valuation', 'Lending category', 'Other groups',
#        'System of National Accounts', 'Alternative conversion factor',
#        'PPP survey year', 'Balance of Payments Manual in use',
#        'External debt Reporting status', 'System of trade',
#        'Government Accounting concept', 'IMF data dissemination standard',
#        'Latest population census', 'Latest household survey',
#        'Source of most recent Income and expenditure data',
#        'Vital registration complete', 'Latest agricultural census',
#        'Latest industrial data', 'Latest trade data', 'Unnamed: 30'],
#       dtype='object')

# %%
df = df[['Short Name','Region', 'Income Group','Lending category', 'Other groups']]

# %%
df.head()
# Out:
#     Short Name                     Region         Income Group  \
# 0        Aruba  Latin America & Caribbean          High income
# 1  Afghanistan                 South Asia           Low income
# 2       Angola         Sub-Saharan Africa  Lower middle income
# 3      Albania      Europe & Central Asia  Upper middle income
# 4      Andorra      Europe & Central Asia          High income
#
#   Lending category Other groups
# 0              NaN          NaN
# 1              IDA         HIPC
# 2             IBRD          NaN
# 3             IBRD          NaN
# 4              NaN          NaN

# %%
df.rename(columns={'Short Name':'Country Name'},inplace=True)

# %%
df_merged = pd.merge(on='Country Name',left=df,right=df_merged)

# %%
df_merged.head()
# Out:
#   Country Name              Region         Income Group Lending category  \
# 0  Afghanistan          South Asia           Low income              IDA
# 1  Afghanistan          South Asia           Low income              IDA
# 2  Afghanistan          South Asia           Low income              IDA
# 3       Angola  Sub-Saharan Africa  Lower middle income             IBRD
# 4       Angola  Sub-Saharan Africa  Lower middle income             IBRD
#
#   Other groups  Happiness Score  Year    EG.ELC.ACCS.ZS SE.PRM.TENR  \
# 0         HIPC            3.575  2015              71.5          ..
# 1         HIPC            3.360  2016  84.1371383666992          ..
# 2         HIPC            3.794  2017                ..          ..
# 3          NaN            4.033  2015                42          ..
# 4          NaN            3.866  2016  40.5206069946289          ..
#
#   NY.ADJ.NNTY.KD.ZG     ...     SH.DYN.MORT SP.POP.TOTL SE.SEC.ENRL.TC.ZS  \
# ...

# %%
df_merged.to_csv('../Datasets/Merged.csv',index=False)
