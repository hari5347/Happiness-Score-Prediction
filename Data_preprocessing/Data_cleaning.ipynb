# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('../Datasets/Merged.csv')

# %%
df.head()
# Out:
#   Country Name  Happiness Score  Year    EG.ELC.ACCS.ZS SE.PRM.TENR  \
# 0  Afghanistan            3.575  2015              71.5          ..
# 1  Afghanistan            3.360  2016  84.1371383666992          ..
# 2  Afghanistan            3.794  2017                ..          ..
# 3      Albania            4.959  2015               100    95.59661
# 4      Albania            4.655  2016               100    95.65855
#
#   NY.ADJ.NNTY.KD.ZG NY.ADJ.NNTY.PC.KD.ZG NY.ADJ.AEDU.GN.ZS NY.ADJ.ICTR.GN.ZS  \
# 0                ..                   ..  2.64374189312687      -10.28844725
# 1                ..                   ..  2.64374189312687      -10.87939183
# 2                ..                   ..                ..                ..
# 3  4.61846802464052     4.92356707507196  3.22728502181027       15.80204856
# 4  3.19661056052152       3.361733691385  3.22728502181027        16.6463675
#
#         SP.POP.DPND     ...     SH.DYN.MORT SP.POP.TOTL SE.SEC.ENRL.TC.ZS  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 36 columns):
# Country Name                414 non-null object
# Happiness Score             414 non-null float64
# Year                        414 non-null int64
# EG.ELC.ACCS.ZS              414 non-null object
# SE.PRM.TENR                 414 non-null object
# NY.ADJ.NNTY.KD.ZG           414 non-null object
# NY.ADJ.NNTY.PC.KD.ZG        414 non-null object
# NY.ADJ.AEDU.GN.ZS           414 non-null object
# NY.ADJ.ICTR.GN.ZS           414 non-null object
# SP.POP.DPND                 414 non-null object
# SP.DYN.CBRT.IN              414 non-null object
# per_si_allsi.cov_q1_tot     414 non-null object
# per_si_allsi.cov_q5_tot     414 non-null object
# per_allsp.cov_pop_tot       414 non-null object
# per_sa_allsa.cov_pop_tot    414 non-null object
# SP.DYN.CDRT.IN              414 non-null object
# SE.XPD.PRIM.ZS              414 non-null object
# ...

# %%
# Out:
#        Happiness Score         Year   SP.POP.TOTL
# count       414.000000   414.000000  4.140000e+02
# mean          5.421382  2016.000000  4.882181e+07
# std           1.157814     0.817484  1.657345e+08
# min           2.693000  2015.000000  3.308150e+05
# 25%           4.513250  2015.000000  4.625137e+06
# 50%           5.334000  2016.000000  1.085579e+07
# 75%           6.360000  2017.000000  3.442615e+07
# max           7.587000  2017.000000  1.386395e+09
